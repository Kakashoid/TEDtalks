# %%
import pandas as pd

df=pd.read_csv('ted_main.csv')
df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
df1=df[['name','comments','duration','views']]
df1
# Out:
#                                                    name  comments  duration  \
# 0             Ken Robinson: Do schools kill creativity?      4553      1164
# 1                  Al Gore: Averting the climate crisis       265       977
# 2                         David Pogue: Simplicity sells       124      1286
# 3                    Majora Carter: Greening the ghetto       200      1116
# 4         Hans Rosling: The best stats you've ever seen       593      1190
# ...                                                 ...       ...       ...
# 2545  Duarte Geraldino: What we're missing in the de...        17       476
# 2546  Armando Azua-Bustos: The most Martian place on...         6       290
# 2547  Radhika Nagpal: What intelligent machines can ...        10       651
# 2548  Theo E.J. Wilson: A black man goes undercover ...        32      1100
# 2549  Karoliina Korppoo: How a video game might help...         8       519
#
#          views
# 0     47227110
# 1      3200520
# ...

# %%
df1.sort_values(by=['views'],ascending=False).head(15) #to play withith
# Out:
#                                                    name  comments  duration  \
# 0             Ken Robinson: Do schools kill creativity?      4553      1164
# 1346  Amy Cuddy: Your body language may shape who yo...      2290      1262
# 677       Simon Sinek: How great leaders inspire action      1930      1084
# 837             Brené Brown: The power of vulnerability      1927      1219
# 452   Mary Roach: 10 things you didn't know about or...       354      1003
# 1776  Julian Treasure: How to speak so that people w...       297       598
# 201             Jill Bolte Taylor: My stroke of insight      2877      1099
# 5                    Tony Robbins: Why we do what we do       672      1305
# 2114  James Veitch: This is what happens when you re...       150       588
# 1416  Cameron Russell: Looks aren't everything. Beli...       846       577
# 500                  Dan Pink: The puzzle of motivation      1094      1116
# ...

# %%
df['duration'].mean()
# Out:
# 826.5101960784314

# %%
df['comments'].mean()
# Out:
# 191.56235294117647

# %%
top15=df1.sort_values(by=['comments'],ascending=False).head(15)

# %%
top15
# Out:
#                                                    name  comments  duration  \
# 96                    Richard Dawkins: Militant atheism      6404      1750
# 0             Ken Robinson: Do schools kill creativity?      4553      1164
# 644      Sam Harris: Science can answer moral questions      3356      1386
# 201             Jill Bolte Taylor: My stroke of insight      2877      1099
# 1787  David Chalmers: How do you explain consciousness?      2673      1117
# 954        Janet Echelman: Taking imagination seriously      2492       566
# 840               Lesley Hazleton: On reading the Koran      2374       573
# 1346  Amy Cuddy: Your body language may shape who yo...      2290      1262
# 661       Michael Specter: The danger of science denial      2272      1141
# 677       Simon Sinek: How great leaders inspire action      1930      1084
# 837             Brené Brown: The power of vulnerability      1927      1219
# ...

# %%
top15.describe()
# Out:
#           comments     duration         views
# count    15.000000    15.000000  1.500000e+01
# mean   2640.333333  1132.666667  1.473881e+07
# std    1308.505454   294.546787  1.636810e+07
# min    1586.000000   566.000000  1.832930e+06
# 25%    1783.500000  1091.500000  2.306250e+06
# 50%    2290.000000  1149.000000  4.374792e+06
# 75%    2775.000000  1249.500000  2.617952e+07
# max    6404.000000  1750.000000  4.722711e+07
